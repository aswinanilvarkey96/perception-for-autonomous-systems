# %%
# !pip list
# Out:
# Package                Version
# ---------------------- ---------
# addict                 2.4.0
# anyio                  3.5.0
# argon2-cffi            21.3.0
# argon2-cffi-bindings   21.2.0
# asttokens              2.0.5
# attrs                  21.4.0
# Babel                  2.9.1
# backcall               0.2.0
# black                  22.1.0
# bleach                 4.1.0
# certifi                2021.10.8
# cffi                   1.15.0
# charset-normalizer     2.0.11
# click                  8.0.3
# colorama               0.4.4
# cycler                 0.11.0
# Cython                 0.29.27
# debugpy                1.5.1
# decorator              5.1.1
# defusedxml             0.7.1
# deprecation            2.1.0
# entrypoints            0.3
# executing              0.8.2
# fonttools              4.29.0
# gitdb                  4.0.9
# GitPython              3.1.26
# idna                   3.3
# imageio                2.14.1
# importlib-resources    5.4.0
# ...
